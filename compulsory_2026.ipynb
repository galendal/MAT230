# %% [markdown]
# # Compulsory exercise in **MAT230 Dynamical Systems** spring 2026.
# Name: [_your name goes here_]
#
# This is the compulsory exercise in **MAT230 Dynamical System** spring semester of 2026. You will need to have this approved to be allowed to take the exam. This assignment will not be graded and does not count to the final grade.
#
# Deadline for submission is **Friday 27. March at 23:59**.
#
# Use this Jupyter-file as a template. Save a copy to you own computer and do the exercise by adding new Python or Markdown cells. Submit the file through Mitt.UiB using your own name as filename.
#
# Collaboration is allowed and encouraged. Use of standard Python libraries, such as _Matplotlib_, _NumPy_, _SciPy_, is allowed.  You may also use AI according to the [guidelines](https://www.uib.no/en/nt/177736/use-artificial-intelligence-ai-faculty-science-and-technology-university-bergen) given by the faculty. I do expect a statement on to what extent AI tools have been used, and reflections on the use are part of the exercise. The final reflection note is an important part of the exercise and will have to be done in order to get it approved.
#
# **Good luck**

# %% [markdown]
# ## The damped and driven pendulum.
#
# We're going to look closer into the dynamics of the driven and damped pendlum. The equations were developed in the lecture on [February 11](https://mitt.uib.no/courses/57337/files/7498083?wrap=1). We will take the non-dimensionalized equation for the driven and damped pendulum:
# $$
# \ddot{\theta}+f\dot{\theta}+\sin{\theta}=F_D cos(ω_D ​t)
# $$
#
# Where:
# - $\theta$ is the angular displacement of the pendulum
#
# - $\omega_D$ is the driving frequency
#
# - $F_D$ is the amplitude of the driving force
#
# - $f$ is the damping coefficient
#
# - The term $f\dot{\theta}$ represents damping proportional to angular velocity
#
# - The term $sin(θ)$ represents the nonlinear restoring force due to gravity
#
# - The term $F_D·cos(ω_D·t)$ represents a periodic driving force

# %% [markdown]
# ## Exercise 1. Preparation
#
# **a)** In a markdown cell, convert the second-order differential equation to a system of two first-order equations. Be short.
#
# **b)** In a Python cell, make a function that evaluates the right-hand side of the resulting ODE system and a routine that solves the problem for given parameters ($\omega_D, \ F_D$ and $f$), and initial conditions $(\theta(0), \dot\theta(0))$.
#
# **c)** Produce a phase map for the undamped ($f=0$) and undriven ($F_D=0$) pendulum.

# %% [markdown]
# **a)** _Your text here_

# %%
# Your code here!

# %% [markdown]
# ## Exercise 2. Phase diagram of the driven and damped pendulum.
#
# **a)** Use $f=0.5$ and $\omega_D=2/3$. Create a table of plots with $\theta(t)$ in the first column and a phase diagram in the second column. For each row, plot the pendulum’s motion when it starts from rest and with $\theta(0)=0$, for $F_D \in [1., 1.2, 1.44, 1.5]$. The figures should have labels on the axes and a title stating the value of the parameters for the individual plots.
#
# **b)** In a markdown cell, reflect on what you're seeing.

# %% [markdown]
# ## Execise 3. Stroboscopic Poincaré map
#
#
# **a)** Create a stroboscopic Poincaré map by sampling the phase space $(\theta, \dot{\theta})$ at times $t_n = n \cdot T_D$, where $T_D = \frac{2\pi}{\omega_D}$ is the period of the driving force. Use the same parameters as _Exercise 2_: $f=0.5$, $\omega_D=2/3$, and $\theta(0)=0$, $\dot{\theta}(0)=0$.
#
# For each value of $F_D \in [1., 1.2, 1.44, 1.5]$:
# - Integrate the system over several driving periods (at least 100 periods to let transients die out)
# - Plot the stroboscopic points on a phase diagram
# - Display all four cases in a single figure with subplots
#
# **b)** In a markdown cell, discuss how the Poincaré map reveals the structure of the attractors and how it changes as $F_D$ increases. Comment on any bifurcations or route to chaos you observe.

# %% [markdown]
# ## Exercise 4. Local Maxima and Time Series Analysis
#
# **a)** Create a function that detects all local maxima in the $\theta(t)$ time series. For the same parameters as in _Exercises 2 and 3_ ($f=0.5$, $\omega_D=2/3$, $\theta(0)=0$, $\dot{\theta}(0)=0$), extract the local maxima of $\theta(t)$ for each value of $F_D \in [1., 1.2, 1.44, 1.5]$.
#
# Plot the results in two ways:
# - A time series plot showing $\theta(t)$ with the local maxima marked
# - A plot of the maximum values as a function of their occurrence number (index)
#
# **b)** Compute and plot the differences between consecutive maxima ($\theta_{max,n+1} - \theta_{max,n}$) as a function of $n$. Create a 2x2 subplot showing this for each $F_D$ value.
#
# **c)** In a markdown cell, discuss what the pattern of local maxima reveals about the system's dynamics. How does the regularity or irregularity of the maxima change with $F_D$? What does this tell you about periodic vs. chaotic motion?

# %% [markdown]
# ## Exercise 5. Bifurcation Diagram
#
# **a)** Create a bifurcation diagram to visualize how the long-term behavior of the pendulum changes as the driving force amplitude $F_D$ increases. Use the same parameters $f=0.5$, $\omega_D=2/3$, with initial conditions $\theta(0)=0$, $\dot{\theta}(0)=0$.
#
# For a range of $F_D$ values from 1.0 to 1.5 (use at least 100 different values):
# - For each $F_D$, integrate the system for a long time to allow transients to decay
# - Collect the stroboscopic points (sampled at $t_n = n \cdot T_D$ where $T_D = \frac{2\pi}{\omega_D}$) after the transient period
# - Plot these points on a diagram with $F_D$ on the horizontal axis and $\theta$ (mod $2\pi$ to keep values in a reasonable range) on the vertical axis
#
# **b)** Enhance the bifurcation diagram by using local maxima instead of stroboscopic sampling. For each $F_D$ value, extract the local maxima of $\theta(t)$ after transients have decayed and plot them against $F_D$.
#
# **c)** In a markdown cell, analyze the bifurcation diagram. Identify:
# - Regions where the motion appears periodic (few discrete points for each $F_D$)
# - Parameter values where bifurcations occur (sudden changes in the number of points)
# - Regions where the motion appears chaotic (dense scatter of points)
# - Compare your observations with the results from Exercises 2-4

# %% [markdown]
# ## Exercise 6. Reflection and AI Usage
#
# **a) Reflection on Observations**
#
# Summarize your key findings from the previous exercises:
# - What transitions did you observe in the system's behavior as $F_D$ increased?
# - How do the different visualization methods (time series, phase diagrams, Poincaré maps, bifurcation diagrams) complement each other in understanding the system?
#
# **b) AI Usage Statement**
#
# Describe the extent to which you used AI tools (such as ChatGPT, GitHub Copilot, or similar) to complete this exercise. Be specific about:
# - Which tasks or code sections were generated with AI assistance?
# - How did you modify or verify the AI-generated code?
# - What aspects did you solve independently?
#
# **c) Reflection on AI in Your Studies**
#
# Reflect on both the benefits and challenges of using AI tools in your learning process:
